# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix,accuracy_score
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
from tkinter import*

# %%
window=Tk()

# %%
window.geometry("1000x325")
window.resizable(width=False,height=True)

# %%
window.title("Breast Cancer Detection")
label1=Label(text="Patient Details",font="none 24 bold")
label1.grid(row=0,column=0)
label2=Label(text="Radius_mean",font="none 10 bold")
label3=Label(text="Texture_mean",font="none 10 bold")
label4=Label(text="Perimeter_mean",font="none 10 bold")
label5=Label(text="Area_mean",font="none 10 bold")
label6=Label(text="Smoothness_mean",font="none 10 bold")
label7=Label(text="Compactness_mean",font="none 10 bold")
label8=Label(text="Concavity_mean",font="none 10 bold")
label9=Label(text="Concave_point_mean",font="none 10 bold")
label10=Label(text="Symmetry_mean",font="none 10 bold")
label11=Label(text="Fractal_dimensions_mean",font="none 10 bold")

label2.grid(row=1,column=0)
label3.grid(row=2,column=0)
label4.grid(row=3,column=0)
label5.grid(row=4,column=0)
label6.grid(row=5,column=0)
label7.grid(row=6,column=0)
label8.grid(row=7,column=0)
label9.grid(row=8,column=0)
label10.grid(row=9,column=0)
label11.grid(row=10,column=0)


label12=Label(text="Radius_se",font="none 10 bold")
label13=Label(text="Texture_se",font="none 10 bold")
label14=Label(text="Perimeter_se",font="none 10 bold")
label15=Label(text="Area_se",font="none 10 bold")
label16=Label(text="Smoothness_se",font="none 10 bold")
label17=Label(text="Compactness_se",font="none 10 bold")
label18=Label(text="Concavity_se",font="none 10 bold")
label19=Label(text="Concave_point_se",font="none 10 bold")
label20=Label(text="Symmetry_se",font="none 10 bold")
label21=Label(text="Fractal_dimensions_se",font="none 10 bold")

label12.grid(row=1,column=2)
label13.grid(row=2,column=2)
label14.grid(row=3,column=2)
label15.grid(row=4,column=2)
label16.grid(row=5,column=2)
label17.grid(row=6,column=2)
label18.grid(row=7,column=2)
label19.grid(row=8,column=2)
label20.grid(row=9,column=2)
label21.grid(row=10,column=2)


label22=Label(text="Radius_worst",font="none 10 bold")
label23=Label(text="Texture_worst",font="none 10 bold")
label24=Label(text="Perimeter_worst",font="none 10 bold")
label25=Label(text="Area_worst",font="none 10 bold")
label26=Label(text="Smoothness_worst",font="none 10 bold")
label27=Label(text="Compactness_worst",font="none 10 bold")
label28=Label(text="Concavity_worst",font="none 10 bold")
label29=Label(text="Concave_point_worst",font="none 10 bold")
label30=Label(text="Symmetry_worst",font="none 10 bold")
label31=Label(text="Fractal_dimensions_worst",font="none 10 bold")

label22.grid(row=1,column=5)
label23.grid(row=2,column=5)
label24.grid(row=3,column=5)
label25.grid(row=4,column=5)
label26.grid(row=5,column=5)
label27.grid(row=6,column=5)
label28.grid(row=7,column=5)
label29.grid(row=8,column=5)
label30.grid(row=9,column=5)
label31.grid(row=10,column=5)

entry1=Entry()
entry2=Entry()
entry3=Entry()
entry4=Entry()
entry5=Entry()
entry6=Entry()
entry7=Entry()
entry8=Entry()
entry9=Entry()
entry10=Entry()

entry1.grid(row=1,column=1)  
entry2.grid(row=2,column=1)
entry3.grid(row=3,column=1)
entry4.grid(row=4,column=1)
entry5.grid(row=5,column=1)
entry6.grid(row=6,column=1)
entry7.grid(row=7,column=1)
entry8.grid(row=8,column=1)
entry9.grid(row=9,column=1)
entry10.grid(row=10,column=1)


entry11=Entry()
entry12=Entry()
entry13=Entry()
entry14=Entry()
entry15=Entry()
entry16=Entry()
entry17=Entry()
entry18=Entry()
entry19=Entry()
entry20=Entry()

entry11.grid(row=1,column=3)  
entry12.grid(row=2,column=3)
entry13.grid(row=3,column=3)
entry14.grid(row=4,column=3)
entry15.grid(row=5,column=3)
entry16.grid(row=6,column=3)
entry17.grid(row=7,column=3)
entry18.grid(row=8,column=3)
entry19.grid(row=9,column=3)
entry20.grid(row=10,column=3)


entry21=Entry()
entry22=Entry()
entry23=Entry()
entry24=Entry()
entry25=Entry()
entry26=Entry()
entry27=Entry()
entry28=Entry()
entry29=Entry()
entry30=Entry()



entry21.grid(row=1,column=6)  
entry22.grid(row=2,column=6)
entry23.grid(row=3,column=6)
entry24.grid(row=4,column=6)
entry25.grid(row=5,column=6)
entry26.grid(row=6,column=6)
entry27.grid(row=7,column=6)
entry28.grid(row=8,column=6)
entry29.grid(row=9,column=6)
entry30.grid(row=10,column=6)
def dele():
    scr.destroy()
    get_ipython().run_cell()

def error(s):
    global scr
    scr=Toplevel(window)
    scr.geometry("225x50")
    scr.title("WARNING")
    l=Label(scr,text=s)
    l.grid(row=0,column=1)
    b=Button(scr,text="OK",command=dele)
    b.grid(row=1,column=2)
def cancer():
    global scr1
    scr1=Toplevel(window)
    scr1.geometry("225x50")
    scr1.title("tumor detection")
    l1=Label(sc1,text="patient has breast cancer", bg="red", fg="white",font="none 10 bold",justify=LEFT)
    l1.grid(row=0,column=1)
    b1=Button(scr1,text="OK",command=dele)
    b1.grid(row=1,column=2)
def non_cancer():
    global scr2
    scr2=Toplevel(window)
    scr2.geometry("225x50")
    scr2.title("tumor detection")
    l2=Label(scr2,text="patient doesnt have breast cancer", bg="green", fg="white",font="none 10 bold",justify=LEFT)
    l2.grid(row=0,column=1)
    b2=Button(scr2,text="OK",command=dele)
    b2.grid(row=1,column=2)   
def cancer_detection():
    try:
        r_mean=float(entry1.get())
        t_mean=float(entry2.get())
        p_mean=float(entry3.get())
        a_mean=float(entry4.get())
        s_mean=float(entry5.get())
        compact_mean=float(entry6.get())
        concavity_mean=float(entry7.get())
        concave_mean=float(entry8.get())
        sym_mean=float(entry9.get())
        frac_mean=float(entry10.get())
      
        r_se=float(entry11.get())
        t_se=float(entry12.get())
        p_se=float(entry13.get())
        a_se=float(entry14.get())
        s_se=float(entry15.get())
        compact_se=float(entry16.get())
        concavity_se=float(entry17.get())
        concave_se=float(entry18.get())
        sym_se=float(entry19.get())
        frac_se=float(entry20.get())
      
        r_w=float(entry21.get())
        t_w=float(entry22.get())
        p_w=float(entry23.get())
        a_w=float(entry24.get())
        s_w=float(entry25.get())
        compact_w=float(entry26.get())
        concavity_w=float(entry27.get())
        concave_w=float(entry28.get())
        sym_w=float(entry29.get())  
        frac_w=float(entry30.get())
    except Exception :
        s="please enter valid number"
        error(s)
        
    breast_cancer = pd.read_csv("data.csv")    
    X=breast_cancer.iloc[:,2:]
    Y = breast_cancer['diagnosis'].values
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
    
    logisticRegr = LogisticRegression(random_state=0)
    logisticRegr.fit(X_train, y_train)
    y_pred = logisticRegr.predict(X_test)
    data2=(r_mean,t_mean,p_mean,a_mean,s_mean,compact_mean,concavity_mean,concave_mean,sym_mean,frac_mean,r_se,t_se,p_se,a_se,s_se,compact_se,concavity_se,concave_se,sym_se,frac_se,r_w,t_w,p_w,a_w,s_w,compact_w,concavity_w,concave_w,sym_w,frac_w)
    data3=np.array(data2)
    data3=data3.reshape(1, -1)
    
    from sklearn.neighbors import KNeighborsClassifier  
    classifier=KNeighborsClassifier(n_neighbors=5) 
    classifier.fit(X_train, y_train) 
    y_pred3 =classifier.predict(X_test)
    
    from sklearn import model_selection
    seed=7
    kfold = model_selection.KFold(n_splits=10, random_state=seed)
    from sklearn import model_selection
    from sklearn.ensemble import VotingClassifier

    estimators=[]
    model1 = LogisticRegression()
    estimators.append(('logistic', model1))
    model2 =  KNeighborsClassifier()
    estimators.append(('knn', model2))
# create the ensemble model
    ensemble = VotingClassifier(estimators)
    results = model_selection.cross_val_score(ensemble, X, Y, cv=kfold)
    ensemble.fit(X_train, y_train)  
    y_pred4=ensemble.predict(X_test) 
    
    ens_pred=ensemble.predict(data3)
    #print(ens_pred)
    if ens_pred[0]=='M':
        lab1=Label(text="patient has breast cancer", bg="red", fg="white",font="none 10 bold",justify=LEFT)
        lab1.grid(row=17,column=0)
        cancer()
    else:
        lab1=Label(text="patient doesnt have breast cancer", bg="green", fg="white",font="none 10 bold",justify=LEFT)
        lab1.grid(row=17,column=0)
        non_cancer()
    
    
    
    
    
    
but=Button(text="SUBMIT",width=20,height=1,command=cancer_detection,font="bold")

but.grid(row=16,column=2)

# %%
window.mainloop()
